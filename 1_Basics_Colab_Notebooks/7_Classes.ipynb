# %%
# Lets make a class for calculating salary based on providing base salary

# %%
class Salary :
  def __init__(self, base_salary, bonus_rate = 0.1, symbol = "$") :
    self.base_salary = base_salary
    self.banus_rate = bonus_rate
    self.bonus = base_salary * bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary * (1 + bonus_rate)

  def base_salary(self) :
    return f"{self.symbol}{self.base_salary:,.2f}"

  def total_salary(self) :
    return f"{self.symbol}{self.total_salary:,.2f}"

  def bonus_rate(self) :
    return f"{self.symbol}{self.bonus_rate}"

  def bonus(self) :
    return f"{self.symbol}{self.bonus:,.2f}"
