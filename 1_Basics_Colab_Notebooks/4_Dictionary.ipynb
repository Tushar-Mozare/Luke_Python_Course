# %%
# Lets have dictionary open

# %%
d1 = {"name": ["Tushar", "Kastu"],
      "age": [20, 20],
      "qualification": ["Businessman", "Doctor"]}

# %%
d1["name"]
# Out:
# ['Tushar', 'Kastu']

# %%
# Let say I want to remove qualification instead add places to live

# %%
d1.pop("qualification")
# Out:
# ['Businessman', 'Doctor']

# %%
d1.update({"place" : ["Delhi", "Amravati"]})

print(d1)
# Out:
# {'name': ['Tushar', 'Kastu'], 'age': [20, 20], 'place': ['Delhi', 'Amravati']}

# %%
#OR
d1['status'] = ['single','commited']

# %%
print(d1)
# Out:
# {'name': ['Tushar', 'Kastu'], 'age': [20, 20], 'place': ['Delhi', 'Amravati'], 'status': ['single', 'commited']}

# %%
# Refer below for info regarding SET
# https://github.com/Tushar-Mozare/Lukes_Python_Course/blob/main/1_Basics/10_Sets.ipynb
