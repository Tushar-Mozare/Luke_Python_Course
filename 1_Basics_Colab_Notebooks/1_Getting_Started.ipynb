# %%
# Assigning Variable

# %%
base_salary = 1000000
bonus_rate = 0.1

# %%
total_salary = (base_salary)*(1 + bonus_rate)

# %%
print(total_salary)
# Out:
# 1100000.0

# %%
# You can assign function too to variable

# %%
p = print

# %%
p(total_salary)
# Out:
# 1100000.0
