# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = load_dataset("lukebarousse/data_jobs")
df = data["train"].to_pandas()

df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
# dataframe.loc[] let you mention columns as str or list instead index that you done in dataframe.iloc[]
# In fisrt example, we slice the column using thier name.

# %%
df.loc[:, "salary_rate" : "salary_hour_avg"].dropna(subset = ["salary_rate", "salary_year_avg"]).head(10)

#OR df.loc[:10, "salary_rate" : "salary_hour_avg"].dropna(subset = ["salary_rate", "salary_year_avg"])
# Out:
#     salary_rate  salary_year_avg  salary_hour_avg
# 28         year         109500.0              NaN
# 77         year         140000.0              NaN
# 92         year         120000.0              NaN
# 100        year         228222.0              NaN
# 109        year          89000.0              NaN
# 116        year         114000.0              NaN
# 146        year         129500.0              NaN
# 180        year          90250.0              NaN
# 212        year         157500.0              NaN
# 257        year         103128.0              NaN

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
# In next example, we mention the specific columns to be displayed.

# %%
df.loc[:][["job_title_short", "job_country", "salary_year_avg"]].dropna(subset = "salary_year_avg").sort_values(by = "salary_year_avg", ascending = False).head(10)
# Out:
#               job_title_short    job_country  salary_year_avg
# 554784         Data Scientist  United States         960000.0
# 665811  Senior Data Scientist   South Africa         890000.0
# 168402           Data Analyst          India         650000.0
# 387378         Data Scientist  United States         585000.0
# 160521         Data Scientist          Sudan         550000.0
# 554140         Data Scientist  United States         525000.0
# 404932          Data Engineer  United States         525000.0
# 417241  Senior Data Scientist  United States         475000.0
# 618461  Senior Data Scientist  United States         463500.0
# 124265         Data Scientist  United States         450000.0

# %%
# Syntax of dataframe.loc[] of pandas
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html

# %%
# Now lets say we want to replace the NaN values of salary_year_avg with the median salary of that column.

# %%
salary_year_avg_median = df.salary_year_avg.median()
df["salary_year_avg"].fillna(salary_year_avg_median)
# Out:
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
#             ...
# 785736    115000.0
# 785737    115000.0
# 785738    115000.0
# 785739    115000.0
# 785740    115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
# Syntax of .fillna() of pandas
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html

# %%
# Now I want to if there is any duplicate entry in the dataframe.

# %%
df.duplicated().any()
# Out:
# True

# %%
# syntax for .duplicated() of pandas
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html

# %%
# Lets say I want to see that duplicates. For that, first I have to create the dataframe out of the above condition.

# %%
df_dup = df[df.duplicated()]
df_dup
# Out:
#              job_title_short                              job_title  \
# 16905         Data Scientist  Consultant - Data Science & Analytics
# 44240         Data Scientist                         Data Scientist
# 54343         Data Scientist             PSAS Science and Analytics
# 57012           Data Analyst                           Data Analyst
# 59403         Data Scientist                         Data Scientist
# ...                      ...                                    ...
# 737894  Senior Data Engineer                   Senior Data Engineer
# 739459          Data Analyst                           Data Analyst
# 750309         Data Engineer           Data Analytics & AI Engineer
# 762489         Data Engineer                          Data Engineer
# 773123        Data Scientist                         Junior Analyst
#
#                  job_location             job_via job_schedule_type  \
# 16905               Hong Kong        via BeBee 香港         Full-time
# 44240   Saint-Gilles, Belgium  via BeBee Belgique         Full-time
# 54343                  Canada     via Trabajo.org         Full-time
# 57012           Brno, Czechia     via Trabajo.org         Full-time
# 59403      Xico, Ver., Mexico     via Trabajo.org         Full-time
# ...                       ...                 ...               ...
# 737894    Toronto, ON, Canada     via Trabajo.org         Full-time
# 739459       Lisbon, Portugal  via BeBee Portugal         Full-time
# 750309    Zürich, Switzerland           via Jobeo         Full-time
# 762489               Anywhere        via LinkedIn         Full-time
# 773123                  Malta     via BeBee Malta         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 16905                False       Hong Kong 2023-02-08 21:47:18
# 44240                False         Belgium 2023-01-05 06:42:48
# 54343                False          Canada 2023-01-15 06:16:22
# 57012                False         Czechia 2023-04-15 06:43:57
# 59403                False          Mexico 2023-01-15 06:19:01
# ...                    ...             ...                 ...
# 737894               False          Canada 2023-11-16 21:13:03
# 739459               False        Portugal 2023-02-27 21:21:41
# 750309               False     Switzerland 2023-05-01 20:24:15
# 762489                True       Argentina 2023-07-25 20:15:59
# 773123               False           Malta 2023-01-10 01:46:11
#
#         job_no_degree_mention  job_health_insurance  job_country salary_rate  \
# 16905                   False                 False    Hong Kong        None
# 44240                   False                 False      Belgium        None
# 54343                   False                 False       Canada        None
# 57012                    True                 False      Czechia        None
# 59403                   False                 False       Mexico        None
# ...                       ...                   ...          ...         ...
# 737894                  False                 False       Canada        None
# 739459                  False                 False     Portugal        None
# 750309                  False                 False  Switzerland        None
# 762489                  False                 False    Argentina        None
# 773123                  False                 False        Malta        None
#
#         salary_year_avg  salary_hour_avg                        company_name  \
# 16905               NaN              NaN                        Sia Partners
# 44240               NaN              NaN                               Smals
# 54343               NaN              NaN                            AbeBooks
# 57012               NaN              NaN                         FE fundinfo
# 59403               NaN              NaN                              Kantar
# ...                 ...              ...                                 ...
# 737894              NaN              NaN                    Loblaw Companies
# 739459              NaN              NaN                             Siemens
# 750309              NaN              NaN                            Swisscom
# 762489              NaN              NaN                             Baufest
# 773123              NaN              NaN  Malta Financial Services Authority
#
#                                                job_skills  \
# 16905                   ['python', 'r', 'sql', 'tableau']
# 44240                       ['r', 'sas', 'sas', 'python']
# 54343   ['java', 'python', 'r', 'sql', 'aws', 'redshif...
# 57012                                                None
# 59403                        ['python', 'r', 'go', 'git']
# ...                                                   ...
# 737894  ['scala', 'sql', 'sql server', 'bigquery', 'az...
# 739459                                               None
# 750309                          ['python', 'sql', 'qlik']
# 762489                          ['sql', 'java', 'oracle']
# 773123                                               None
#
#                                           job_type_skills
# 16905   {'analyst_tools': ['tableau'], 'programming': ...
# 44240   {'analyst_tools': ['sas'], 'programming': ['r'...
# 54343   {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 57012                                                None
# 59403   {'other': ['git'], 'programming': ['python', '...
# ...                                                   ...
# 737894  {'cloud': ['bigquery', 'azure', 'databricks', ...
# 739459                                               None
# 750309  {'analyst_tools': ['qlik'], 'programming': ['p...
# 762489  {'cloud': ['oracle'], 'programming': ['sql', '...
# 773123                                               None
#
# [101 rows x 17 columns]

# %%
# Now I want  to get rid of these duplicate, for that

# %%
df_cleaned = df.drop_duplicates()
df_cleaned
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785640 rows x 17 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785640 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785640 non-null  object
#  1   job_title              785639 non-null  object
#  2   job_location           784595 non-null  object
#  3   job_via                785632 non-null  object
#  4   job_schedule_type      772975 non-null  object
#  5   job_work_from_home     785640 non-null  bool
#  6   search_location        785640 non-null  object
#  7   job_posted_date        785640 non-null  datetime64[ns]
#  8   job_no_degree_mention  785640 non-null  bool
#  9   job_health_insurance   785640 non-null  bool
#  10  job_country            785591 non-null  object
#  11  salary_rate            33066 non-null   object
#  12  salary_year_avg        22002 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785622 non-null  object
#  15  job_skills             668654 non-null  object
#  16  job_type_skills        668654 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 92.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
# We can see there is reduction in the no of rows in df_cleaned and df. Thus df_cleaned is dataframe without duplicates.

# %%
# Syntax for .drop_duplicates() for pandas
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

# %%
# Now let say I want to check only centain no of columns for duplication
# Say for job_title and company_name. Do any same company have resistered same job title many times
# Remember, here we are using  and logic, that means if entry in job_title have exact values in many rows along with 
# entry in company_name have exact values in many rows, then and only it will return True.

# %%
df_cleaned.duplicated(subset = ["job_title", "company_name"]).any()
# Out:
# True

# %%
# Ohh oo, we have such remove this entries.

# %%
df_cleaned = df_cleaned.drop_duplicates(subset = ["job_title", "company_name"])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 508042 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        508042 non-null  object
#  1   job_title              508041 non-null  object
#  2   job_location           507389 non-null  object
#  3   job_via                508042 non-null  object
#  4   job_schedule_type      499091 non-null  object
#  5   job_work_from_home     508042 non-null  bool
#  6   search_location        508042 non-null  object
#  7   job_posted_date        508042 non-null  datetime64[ns]
#  8   job_no_degree_mention  508042 non-null  bool
#  9   job_health_insurance   508042 non-null  bool
#  10  job_country            507997 non-null  object
#  11  salary_rate            20620 non-null   object
#  12  salary_year_avg        13091 non-null   float64
#  13  salary_hour_avg        7233 non-null    float64
#  14  company_name           508027 non-null  object
#  15  job_skills             424837 non-null  object
#  16  job_type_skills        424837 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 59.6+ MB

# %%
#Now if want a random sample of the dataframe

# %%
df.sample(10)
# Out:
#              job_title_short                                     job_title  \
# 182623         Data Engineer   REMOTE - Data Engineer / Developer (Python)
# 680439  Senior Data Engineer                          Senior Data Engineer
# 149732         Data Engineer                         Data Engineer - Herts
# 747006          Data Analyst                             Lead Data Analyst
# 327608  Senior Data Engineer                       Senior BI Data Engineer
# 374494         Data Engineer                            Data Engineer, Mid
# 450679         Data Engineer                            Data Engineer Lead
# 507844         Data Engineer                             Sr. Data Engineer
# 322379          Data Analyst  Data & Analytics Manager (Sustainable Energy
# 776577         Data Engineer                           Azure data Engineer
#
#                         job_location             job_via job_schedule_type  \
# 182623                Costa Mesa, CA        via LinkedIn        Contractor
# 680439       New Delhi, Delhi, India        via LinkedIn         Full-time
# 149732             Hertfordshire, UK    via Leisure Jobs         Full-time
# 747006  Dubai - United Arab Emirates        via LinkedIn         Full-time
# 327608              Lisbon, Portugal  via BeBee Portugal         Full-time
# 374494                  Bethesda, MD          via Adzuna         Full-time
# 450679        Amsterdam, Netherlands        via LinkedIn         Full-time
# 507844           Toronto, ON, Canada    via BeBee Canada         Full-time
# 322379            Noord, Netherlands           via BeBee         Full-time
# 776577   Hyderabad, Telangana, India        via LinkedIn         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 182623               False                   Sudan 2023-03-28 16:27:44
# 680439               False                   India 2023-05-05 10:30:23
# 149732               False          United Kingdom 2023-08-21 08:15:55
# 747006               False    United Arab Emirates 2023-11-27 21:08:38
# 327608               False                Portugal 2023-06-06 23:30:50
# 374494               False  Florida, United States 2023-03-08 18:10:01
# 450679               False             Netherlands 2023-09-07 14:30:30
# 507844               False                  Canada 2023-01-02 11:30:20
# 322379               False             Netherlands 2023-07-23 17:29:43
# 776577               False                   India 2023-01-19 06:14:13
#
#         job_no_degree_mention  job_health_insurance           job_country  \
# 182623                  False                  True                 Sudan
# 680439                  False                 False                 India
# 149732                   True                 False        United Kingdom
# 747006                   True                 False  United Arab Emirates
# 327608                  False                 False              Portugal
# 374494                  False                  True         United States
# 450679                  False                 False           Netherlands
# 507844                  False                 False                Canada
# 322379                  False                 False           Netherlands
# 776577                   True                 False                 India
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 182623        None              NaN              NaN
# 680439        None              NaN              NaN
# 149732        None              NaN              NaN
# 747006        None              NaN              NaN
# 327608        None              NaN              NaN
# 374494        None              NaN              NaN
# 450679        None              NaN              NaN
# 507844        None              NaN              NaN
# 322379        None              NaN              NaN
# 776577        None              NaN              NaN
#
#                             company_name  \
# 182623           Platinum Resource Group
# 680439           Perfect Job Consultancy
# 149732                    Haven Holidays
# 747006                    SGP Technology
# 327608                          ConvaTec
# 374494               Booz Allen Hamilton
# 450679                             ORTEC
# 507844                      Diverse Lynx
# 322379        Noord-Holland, Netherlands
# 776577  GITS RECRUITMENT PRIVATE LIMITED
#
#                                                job_skills  \
# 182623  ['python', 'sql', 'nosql', 'postgresql', 'excel']
# 680439  ['sql', 'java', 'python', 'aws', 'gcp', 'azure...
# 149732  ['sql', 'snowflake', 'aws', 'redshift', 'azure...
# 747006  ['sql', 'python', 'r', 'excel', 'tableau', 'po...
# 327608  ['sql', 'mysql', 'sql server', 'oracle', 'ssis...
# 374494           ['sql', 'nosql', 'elasticsearch', 'aws']
# 450679                 ['go', 'azure', 'power bi', 'dax']
# 507844              ['python', 'sql', 'scala', 'pyspark']
# 322379          ['sql', 'python', 'bigquery', 'power bi']
# 776577  ['sql', 'shell', 'powershell', 'azure', 'datab...
#
#                                           job_type_skills
# 182623  {'analyst_tools': ['excel'], 'databases': ['po...
# 680439  {'cloud': ['aws', 'gcp', 'azure'], 'libraries'...
# 149732  {'cloud': ['snowflake', 'aws', 'redshift', 'az...
# 747006  {'analyst_tools': ['excel', 'tableau', 'power ...
# 327608  {'analyst_tools': ['ssis', 'tableau', 'power b...
# 374494  {'cloud': ['aws'], 'databases': ['elasticsearc...
# 450679  {'analyst_tools': ['power bi', 'dax'], 'cloud'...
# 507844  {'libraries': ['pyspark'], 'programming': ['py...
# 322379  {'analyst_tools': ['power bi'], 'cloud': ['big...
# 776577  {'cloud': ['azure', 'databricks'], 'other': ['...

# %%
# Say I wamt a same sample every time

# %%
df.sample(5 , random_state = 42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}

# %%
df.sample(5 , random_state = 42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None              NaN              NaN           ManpowerGroup
# 406337        None              NaN              NaN                 Harnham
# 659951        None              NaN              NaN             Morgan King
# 541593        None              NaN              NaN                 Konnekt
# 425158        None              NaN              NaN  Independent Recruiters
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}

# %%
# Syntax of dataframe.sample() of pandas
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sample.html

# %%
# If I want to make a copy of a dataframe

# %%
df_og = df.copy()

# %%
id(df) == id(df_og)
# Out:
# False

# %%
# See the ids of df and df_og datarame are different
# that means if I make changes in df it does not affect the df_og and vice versa
# If I assign with "=" then both variables point towords same dataframe which will reflect in having same id.
# Thus, changes made in one will reflect in the other

# %%
df_link = df

# %%
id(df) == id(df_link)
# Out:
# True

# %%
# Syntax of .copy() for pandas
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.copy.html

# %%
# Lets understand the pivot table
# Here, the syntax : [.pivot_table()]
# https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# index represent row 
# columns represent column

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 508042 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        508042 non-null  object
#  1   job_title              508041 non-null  object
#  2   job_location           507389 non-null  object
#  3   job_via                508042 non-null  object
#  4   job_schedule_type      499091 non-null  object
#  5   job_work_from_home     508042 non-null  bool
#  6   search_location        508042 non-null  object
#  7   job_posted_date        508042 non-null  datetime64[ns]
#  8   job_no_degree_mention  508042 non-null  bool
#  9   job_health_insurance   508042 non-null  bool
#  10  job_country            507997 non-null  object
#  11  salary_rate            20620 non-null   object
#  12  salary_year_avg        13091 non-null   float64
#  13  salary_hour_avg        7233 non-null    float64
#  14  company_name           508027 non-null  object
#  15  job_skills             424837 non-null  object
#  16  job_type_skills        424837 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 59.6+ MB

# %%
# Let say I want a table representing average salary of different job title of individual companies
# Take job_title_short, company_name, and salary_year_avg

# %%
df_cleaned = df_cleaned.dropna(subset = "salary_year_avg")

# %%
df_cleaned["salary_year_avg"].isna().any()
# Out:
# False

# %%
df_cleaned.pivot_table(index = "company_name", columns = "job_title_short", values = "salary_year_avg", aggfunc = "mean")
# Out:
# job_title_short                     Business Analyst  Cloud Engineer  \
# company_name
# #twiceasnice Recruiting                          NaN             NaN
# /dev/color                                       NaN             NaN
# 0nward Select                                    NaN             NaN
# 1 Point System LLC.                              NaN             NaN
# 1-800-FLOWERS.COM, INC.                          NaN             NaN
# ...                                              ...             ...
# zooplus SE                                       NaN             NaN
# ztp                                              NaN             NaN
# ЛАНИТ                                            NaN             NaN
# Технологическая компания                         NaN        280000.0
# ​Illinois State Board of Education               NaN             NaN
#
# job_title_short                      Data Analyst  Data Engineer  \
# company_name
# #twiceasnice Recruiting              63666.666667            NaN
# /dev/color                                    NaN            NaN
# 0nward Select                        92500.000000            NaN
# 1 Point System LLC.                           NaN       170000.0
# 1-800-FLOWERS.COM, INC.                       NaN            NaN
# ...                                           ...            ...
# zooplus SE                                    NaN            NaN
# ztp                                           NaN        95000.0
# ЛАНИТ                               400000.000000            NaN
# Технологическая компания                      NaN            NaN
# ​Illinois State Board of Education   62536.000000            NaN
#
# job_title_short                     Data Scientist  Machine Learning Engineer  \
# company_name
# #twiceasnice Recruiting                        NaN                        NaN
# /dev/color                                125000.0                        NaN
# 0nward Select                                  NaN                        NaN
# 1 Point System LLC.                            NaN                        NaN
# 1-800-FLOWERS.COM, INC.                        NaN                        NaN
# ...                                            ...                        ...
# zooplus SE                                     NaN                   166000.0
# ztp                                            NaN                        NaN
# ЛАНИТ                                          NaN                        NaN
# Технологическая компания                       NaN                        NaN
# ​Illinois State Board of Education             NaN                        NaN
#
# job_title_short                     Senior Data Analyst  Senior Data Engineer  \
# company_name
# #twiceasnice Recruiting                        120000.0                   NaN
# /dev/color                                          NaN                   NaN
# 0nward Select                                       NaN                   NaN
# 1 Point System LLC.                                 NaN                   NaN
# 1-800-FLOWERS.COM, INC.                             NaN                   NaN
# ...                                                 ...                   ...
# zooplus SE                                          NaN                   NaN
# ztp                                                 NaN                   NaN
# ЛАНИТ                                               NaN                   NaN
# Технологическая компания                            NaN                   NaN
# ​Illinois State Board of Education                  NaN                   NaN
#
# job_title_short                     Senior Data Scientist  Software Engineer
# company_name
# #twiceasnice Recruiting                               NaN                NaN
# /dev/color                                            NaN                NaN
# 0nward Select                                         NaN                NaN
# 1 Point System LLC.                                   NaN                NaN
# 1-800-FLOWERS.COM, INC.                          190000.0                NaN
# ...                                                   ...                ...
# zooplus SE                                            NaN                NaN
# ztp                                                   NaN                NaN
# ЛАНИТ                                                 NaN                NaN
# Технологическая компания                              NaN                NaN
# ​Illinois State Board of Education                    NaN                NaN
#
# [6344 rows x 10 columns]
